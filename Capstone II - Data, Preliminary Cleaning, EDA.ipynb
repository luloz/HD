# %% [markdown]
# # Capstone II
# Luis Lozada

# %% [markdown]
# 1. Identifies which of the three proposals you outlined in your lightning talk you have chosen <br>
#       <br>
#     <b>Heart Disease Prediction
# ***
# 2. Articulates the main goal of your project (your problem statement) <br>
#     <br>
#     Heart Disease is the leading cause of death in the United States, ahead of cancer, respiratory infection, and accidents. For this reason, I think it vital to inform individuals of their risk. My goal is to great a regression model which predicts a patient's risk for heart disease given their demographic information, medical examination (blood pressure, labs, illnesses), and lifestyle (smoking, diet).
# ***
# 3. Outlines your proposed methods and models <br>
#     <br>
#     All data will come from publicly available governmental sources and include demographic, locational, and self survey.
#         1. Inspect datasets (and data dictionaries) for inclusion in the project
#         2. If pass, preliminary cleaning, eda, sanity checks
#         3. Arrive at clean dataset
#         4. Build a Linear Regression Model to get a baseline
#         5. Go from there... (I'm not sure what I will find so it is difficult for me to predict)
# ***
# 4. Defines the risks & assumptions of your data<br>
#     <br>
#     The benefit of using publicly available data is that much of it is already in CSV format. However, this implies heavy preprocessing on the hands of the primary researchers which I am not privy to. There is also the problem of selection bias when it comes to the survey data. The vast majority of data is of people which suffer from heart disease as oppossed ot healthy individuals.
# ***
# 5. Revises initial goals & success criteria, as needed<br>
#     <br>
#     kk
# ***
# 6. Document your data source<br>
#     <br>
#     1. https://www.kaggle.com/cdc/national-health-and-nutrition-examination-survey
#     2. https://chronicdata.cdc.gov/Heart-Disease-Stroke-Prevention/Behavioral-Risk-Factor-Data-Heart-Disease-Stroke-P/4ny5-qn3w
#     3. https://www.kaggle.com/cdc/mortality
# ***
# 7. Performs & summarizes preliminary EDA of your data

# %% [markdown]
# # National Health and Nutrition Examination Survey
# ## NHANES datasets from 2013-2014

# %%
import pandas as pd

# %%
demographics = pd.read_csv('/Users/lu/Dropbox/Capstone/Data/national-health-and-nutrition-examination-survey/demographic.csv')

# %% [markdown]
# # Demographics Data Dictionary
#      'SEQN' - Respondent sequence number.
#      'RIAGENDR' - Gender of participant
#      'RIDAGEYR' - Age in Year, top coded 80
#      'RIDAGEMN' - Age in months at time of screening, top coded 959 SO MANY NULLS
#      'RIDRETH1' - Recode of reported race and Hispanic origin information
#      'RIDRETH3' - Recode of reported race and Hispanic origin information, with Non-Hispanic Asian Category
#      'RIDEXMON' - Six month time period when the examination was performed - two categories: November 1 through April 30, May 1 through October 31.
#      'RIDEXAGM' - Age in months at time of examination
#      'DMQMILIZ' - Military Service 1.0 = yes, 2.0 = no, 7.0 error?
#      'DMQADFC' - Served in foreign country during military service
#      'DMDBORN4' - What country were you born, seems like the vast majority are 1 which probably means US
#      'DMDCITZN' - Citizenship?
#      'DMDYRSUS' - Length of time the participant has been in the US.
#      'DMDEDUC3' -
#      'DMDEDUC2',
#      'DMDMARTL',
#      'RIDEXPRG',
#      'SIALANG' - Language used for sampling
#      'SIAPROXY' - language proxy
#      'SIAINTRP' - interpretor used
#      'FIALANG' - family interview language
#      'FIAPROXY' - proxy used for family interview
#      'FIAINTRP' - interpretor used for family
#      'MIALANG',
#      'MIAPROXY',
#      'MIAINTRP',
#      'AIALANGA',
#      'DMDHHSIZ' - Total number of people in household
#      'DMDFMSIZ' - Total number of people in family
#      'DMDHHSZA'- num children >=5 in household
#      'DMDHHSZB' - num children 6-17 in household
#      'DMDHHSZE',
#      'DMDHRGND',
#      'DMDHRAGE',
#      'DMDHRBR4',
#      'DMDHREDU',
#      'DMDHRMAR',
#      'DMDHSEDU',
#      'WTINT2YR',
#      'WTMEC2YR',
#      'SDMVPSU',
#      'SDMVSTRA',
#      'INDHHIN2',
#      'INDFMIN2',
#      'INDFMPIR']

# %%
list(demographics.columns[(demographics.isnull().sum() > 1000)]) # more than 1000 nulls in column
# Out:
# ['RIDAGEMN',
#  'RIDEXAGM',
#  'DMQMILIZ',
#  'DMQADFC',
#  'DMDYRSUS',
#  'DMDEDUC3',
#  'DMDEDUC2',
#  'DMDMARTL',
#  'RIDEXPRG',
#  'MIALANG',
#  'MIAPROXY',
#  'MIAINTRP',
#  'AIALANGA',
#  'DMDHSEDU']

# %%
demographics[demographics.columns[(demographics.isnull().sum() > 1000)]].head()
# Out:
#    RIDAGEMN  RIDEXAGM  DMQMILIZ  DMQADFC  DMDYRSUS  DMDEDUC3  DMDEDUC2  \
# 0       NaN       NaN       1.0      1.0       NaN       NaN       3.0
# 1       NaN       NaN       2.0      NaN       NaN       NaN       3.0
# 2       NaN       NaN       1.0      1.0       NaN       NaN       4.0
# 3       NaN     119.0       NaN      NaN       NaN       3.0       NaN
# 4       NaN       NaN       2.0      NaN       NaN       NaN       5.0
#
#    DMDMARTL  RIDEXPRG  MIALANG  MIAPROXY  MIAINTRP  AIALANGA  DMDHSEDU
# 0       4.0       NaN      1.0       2.0       2.0       1.0       NaN
# 1       1.0       NaN      1.0       2.0       2.0       1.0       1.0
# 2       1.0       NaN      1.0       2.0       2.0       NaN       3.0
# 3       NaN       NaN      1.0       2.0       2.0       1.0       4.0
# 4       1.0       NaN      1.0       2.0       2.0       NaN       5.0

# %%
demographics.drop(demographics.columns[(demographics.isnull().sum() > 1000)], axis=1, inplace=True) #dropping all columns with over 1k nulls

# %%
list(demographics.columns)
# Out:
# ['SEQN',
#  'SDDSRVYR',
#  'RIDSTATR',
#  'RIAGENDR',
#  'RIDAGEYR',
#  'RIDRETH1',
#  'RIDRETH3',
#  'RIDEXMON',
#  'DMDBORN4',
#  'DMDCITZN',
#  'SIALANG',
#  'SIAPROXY',
#  'SIAINTRP',
#  'FIALANG',
#  'FIAPROXY',
#  'FIAINTRP',
#  'DMDHHSIZ',
#  'DMDFMSIZ',
#  'DMDHHSZA',
#  'DMDHHSZB',
#  'DMDHHSZE',
#  'DMDHRGND',
#  'DMDHRAGE',
#  'DMDHRBR4',
#  'DMDHREDU',
#  'DMDHRMAR',
#  'WTINT2YR',
#  'WTMEC2YR',
#  'SDMVPSU',
#  'SDMVSTRA',
#  'INDHHIN2',
#  'INDFMIN2',
#  'INDFMPIR']

# %%
important_demo = ['SEQN', 'RIAGENDR', 'RIDAGEYR', 'RIDRETH1', 'RIDRETH3', 'RIDEXMON', 'DMDBORN4', 'DMDCITZN', 'SIALANG', 'SIAINTRP', 'FIALANG',
                 'FIAPROXY', 'FIAINTRP', 'DMDHHSIZ', 'DMDHHSZA', 'DMDHHSZB', '']

# %%
demographics['FIALANG'].value_counts() # family
# Out:
# 1.0    9417
# 2.0     637
# Name: FIALANG, dtype: int64

# %%
demographics['SIAINTRP'].value_counts() #was an interpretor used?
# Out:
# 2    9833
# 1     342
# Name: SIAINTRP, dtype: int64

# %%
demographics['SIALANG'].value_counts() # language of screening
# Out:
# 1    9100
# 2    1075
# Name: SIALANG, dtype: int64

# %%
demographics['DMDCITZN'].value_counts() # maybe a citizenship questions?
# Out:
# 1.0    9220
# 2.0     944
# 7.0       4
# 9.0       3
# Name: DMDCITZN, dtype: int64

# %%
# these are columns I intend to drop wholesale 
to_drop = ['SDDSRVYR', 'RIDSTATR', 'RIDAGEMN', 'DMQADFC', 'DMDYRSUS', ]

# %%
demographics['DMQMILIZ'].value_counts() 
# 2.0 = no
# 1.0 = yes
# one error
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'DMQMILIZ'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-bae57828a44a> in <module>()
# ...

# %%
demographics[(demographics['DMQMILIZ'] == 7.0)] # error at index = 5275

# %%
demographics['DMQADFC'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'DMQADFC'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-a35351cf2c27> in <module>()
# ...

# %%
demographics['DMDBORN4'].value_counts()
# Out:
# 1     8262
# 2     1908
# 77       4
# 99       1
# Name: DMDBORN4, dtype: int64

# %%
demographics['DMDYRSUS'].value_counts()
# Out:
# 6.0     342
# 4.0     298
# 7.0     246
# 3.0     234
# 5.0     210
# 2.0     170
# 8.0     146
# 9.0     106
# 1.0      70
# 99.0     45
# 77.0     41
# Name: DMDYRSUS, dtype: int64

# %%
# Out:
# [9.0     44
#  6.0     44
#  1.0     42
#  8.0     39
#  5.0     38
#  4.0     33
#  7.0     32
#  10.0    31
#  23.0    30
#  15.0    29
#  0.0     28
#  3.0     28
#  13.0    27
#  2.0     26
#  18.0    25
#  17.0    24
#  22.0    22
#  16.0    21
#  12.0    20
#  11.0    20
#  20.0    18
#  21.0    16
#  14.0    16
#  19.0    12
#  24.0     8
#  Name: RIDAGEMN, dtype: int64, 5.0      43
#  7.0      40
#  2.0      39
#  6.0      37
#  10.0     37
#  34.0     36
#  9.0      35
#  8.0      34
#  16.0     32
#  119.0    31
#  1.0      30
#  11.0     29
#  144.0    27
#  153.0    27
#  24.0     27
#  86.0     26
#  91.0     25
#  128.0    25
#  27.0     25
#  47.0     25
#  163.0    24
#  52.0     24
#  66.0     24
#  96.0     24
#  107.0    24
#  170.0    24
#  193.0    24
#  23.0     24
#  142.0    23
#  78.0     23
#           ..
#  186.0    11
#  222.0    11
#  179.0    11
#  152.0    11
#  136.0    11
#  54.0     11
#  202.0    10
#  37.0     10
#  156.0    10
#  215.0    10
# ...

# %%
list(demographics.columns[(demographics.isnull().sum() > 1000)])
# Out:
# ['RIDAGEMN',
#  'RIDEXAGM',
#  'DMQMILIZ',
#  'DMQADFC',
#  'DMDYRSUS',
#  'DMDEDUC3',
#  'DMDEDUC2',
#  'DMDMARTL',
#  'RIDEXPRG',
#  'MIALANG',
#  'MIAPROXY',
#  'MIAINTRP',
#  'AIALANGA',
#  'DMDHSEDU']

# %%
diet = pd.read_csv('/Users/lu/Dropbox/Capstone/Data/national-health-and-nutrition-examination-survey/diet.csv')

# %%
exam = pd.read_csv('/Users/lu/Dropbox/Capstone/Data/national-health-and-nutrition-examination-survey/examination.csv')

# %%
labs = pd.read_csv('/Users/lu/Dropbox/Capstone/Data/national-health-and-nutrition-examination-survey/labs.csv')

# %%
meds = pd.read_csv('/Users/lu/Dropbox/Capstone/Data/national-health-and-nutrition-examination-survey/medications.csv', encoding='unicode_escape')

# %%
questionnaire = pd.read_csv('/Users/lu/Dropbox/Capstone/Data/national-health-and-nutrition-examination-survey/questionnaire.csv')

# %%
data = [demographics, diet, exam, labs, meds, questionnaire]

# %%
for each in data:
    print(each.shape)
# Out:
# (10175, 33)
# (9813, 168)
# (9813, 224)
# (9813, 424)
# (20194, 13)
# (10175, 953)

# %%
(demographics.columns) & (diet.columns) & (exam.columns) & (labs.columns) & (meds.columns) & (questionnaire.columns)
# Out:
# Index(['SEQN'], dtype='object')

# %%
demographics
# Out:
#         SEQN  SDDSRVYR  RIDSTATR  RIAGENDR  RIDAGEYR  RIDAGEMN  RIDRETH1  \
# 0      73557         8         2         1        69       NaN         4
# 1      73558         8         2         1        54       NaN         3
# 2      73559         8         2         1        72       NaN         3
# 3      73560         8         2         1         9       NaN         3
# 4      73561         8         2         2        73       NaN         3
# 5      73562         8         2         1        56       NaN         1
# 6      73563         8         2         1         0       5.0         3
# 7      73564         8         2         2        61       NaN         3
# 8      73565         8         1         1        42       NaN         2
# 9      73566         8         2         2        56       NaN         3
# 10     73567         8         2         1        65       NaN         3
# 11     73568         8         2         2        26       NaN         3
# ...

# %%
demodiet = pd.merge(demographics, diet, on='SEQN')

# %%
pd.merge(demodiet, exam, on='SEQN')
# Out:
#        SEQN  SDDSRVYR  RIDSTATR  RIAGENDR  RIDAGEYR  RIDAGEMN  RIDRETH1  \
# 0     73557         8         2         1        69       NaN         4
# 1     73558         8         2         1        54       NaN         3
# 2     73559         8         2         1        72       NaN         3
# 3     73560         8         2         1         9       NaN         3
# 4     73561         8         2         2        73       NaN         3
# 5     73562         8         2         1        56       NaN         1
# 6     73563         8         2         1         0       5.0         3
# 7     73564         8         2         2        61       NaN         3
# 8     73566         8         2         2        56       NaN         3
# 9     73567         8         2         1        65       NaN         3
# 10    73568         8         2         2        26       NaN         3
# 11    73570         8         2         2         9       NaN         5
# ...

# %%
#demographics, diet, exam, labs, meds, questionnaire
# Out:
#   File "<ipython-input-29-bc0fd04d6b58>", line 2
#     print each
#              ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(each)?

# %%
diet.head()
# Out:
#     SEQN         WTDRD1         WTDR2D  DR1DRSTZ  DR1EXMER  DRABF  DRDINT  \
# 0  73557   16888.327864   12930.890649         1      49.0    2.0     2.0
# 1  73558   17932.143865   12684.148869         1      59.0    2.0     2.0
# 2  73559   59641.812930   39394.236709         1      49.0    2.0     2.0
# 3  73560  142203.069917  125966.366442         1      54.0    2.0     2.0
# 4  73561   59052.357033   39004.892993         1      63.0    2.0     2.0
#
#    DR1DBIH  DR1DAY  DR1LANG   ...     DRD370QQ  DRD370R  DRD370RQ  DRD370S  \
# 0      6.0     2.0      1.0   ...          NaN      NaN       NaN      NaN
# 1      4.0     1.0      1.0   ...          NaN      2.0       NaN      2.0
# 2     18.0     6.0      1.0   ...          NaN      NaN       NaN      NaN
# 3     21.0     3.0      1.0   ...          NaN      NaN       NaN      NaN
# 4     18.0     1.0      1.0   ...          NaN      2.0       NaN      2.0
#
#    DRD370SQ  DRD370T  DRD370TQ  DRD370U  DRD370UQ  DRD370V
# ...

# %% [markdown]
# # Behavioral Risk Factor Data: Heart Disease & Stroke Prevention
# CDC

# %%
df = pd.read_csv('/Users/lu/Dropbox/Capstone/Data/dataset.csv')

# %%
df.shape
# Out:
# (85800, 29)

# %%
df.head()
# Out:
#    Year LocationAbbr LocationDesc Datasource PriorityArea1 PriorityArea2  \
# 0  2011           AL      Alabama      BRFSS          None          None
# 1  2011           AL      Alabama      BRFSS          None          None
# 2  2011           AL      Alabama      BRFSS          None          None
# 3  2011           AL      Alabama      BRFSS          None          None
# 4  2011           AL      Alabama      BRFSS          None          None
#
#   PriorityArea3 PriorityArea4                 Category  \
# 0          None          None  Cardiovascular Diseases
# 1          None          None  Cardiovascular Diseases
# 2          None          None  Cardiovascular Diseases
# 3          None          None  Cardiovascular Diseases
# 4          None          None  Cardiovascular Diseases
#
#                           Topic                   ...                     \
# 0  Major Cardiovascular Disease                   ...
# 1  Major Cardiovascular Disease                   ...
# ...

# %%
list(df.columns)
# Out:
# ['Year',
#  'LocationAbbr',
#  'LocationDesc',
#  'Datasource',
#  'PriorityArea1',
#  'PriorityArea2',
#  'PriorityArea3',
#  'PriorityArea4',
#  'Category',
#  'Topic',
#  'Indicator',
#  'Data_Value_Type',
#  'Data_Value_Unit',
#  'Data_Value',
#  'Data_Value_Alt',
#  'Data_Value_Footnote_Symbol',
#  'Data_Value_Footnote',
#  'Confidence_Limit_Low',
#  'Confidence_Limit_High',
#  'Break_Out_Category',
#  'Break_out',
#  'CategoryID',
#  'TopicID',
#  'IndicatorID',
#  'Data_Value_TypeID',
#  'BreakoutCategoryID',
#  'BreakOutID',
#  'LocationID',
#  'GeoLocation']

# %% [markdown]
# ## Data Dictionary
#
#     Year - Year
#     LocationAbbr - Two letter State Abbreviation
#     LocationDesc - Location description
#     Datasource - Abbreviation of data source
#     PriorityArea1
#     PriorityArea2
#     PriorityArea3
#     PriorityArea4
#     Category - Category description
#     Topic - Topic description
#     Indicator - Indicator description
#     Data_Value_Type - Data Value Type (mean, rate, percentage)
#     Data_Value_Unit - Data Value Unit (%, rate per 100,000, etc.)
#     Data_Value  - Data value (point estimate)
#     Data_Value_Alt - Equal to data value, but formatting is numeric
#     Data_Value_Footnote_Symbol - Symbol that would be used to flag footnotes
#     Data_Value_Footnote - Footnote description
#     Confidence_Limit_Low - 95% confidence interval lower bound
#     Confidence_Limit_High - 95% confidence interval upper bound
#     Break_Out_Category - Break out category description
#     Break_out - Break out group description
#     CategoryID - Category lookup value
#     TopicID - Topic lookup value
#     IndicatorID - Indicator lookup value
#     Data_Value_TypeID - Data value type lookup value
#     BreakoutCategoryID - Break out category lookup value
#     BreakOutID - Break out group lookup value
#     LocationID - Location lookup value
#     GeoLocation - Latitude & Longitude to be provided for formatting GeoLocation or Geocode in the format (latitude, longitude)

# %%
df['Data_Value_Type'].value_counts()
# Out:
# Crude               54600
# Age-Standardized    31200
# Name: Data_Value_Type, dtype: int64

# %%
df['Data_Value_Unit'].value_counts()
# Out:
# Percent (%)    85800
# Name: Data_Value_Unit, dtype: int64

# %% [markdown]
# C2 = Risk Factors, C1 = Cardiovascular Disease

# %%
df['Category'].value_counts()
# Out:
# Risk Factors               57200
# Cardiovascular Diseases    28600
# Name: Category, dtype: int64

# %%
df['CategoryID'].value_counts()
# Out:
# C2    57200
# C1    28600
# Name: CategoryID, dtype: int64

# %%
df['Topic'].value_counts() # will this be my y? 
# the Heart Attack?
# Out:
# Hypertension                                  11440
# Cholesterol Abnormalities                     11440
# Acute Myocardial Infarction (Heart Attack)    11440
# Obesity                                       11440
# Diabetes                                       5720
# Physical Inactivity                            5720
# Nutrition                                      5720
# Major Cardiovascular Disease                   5720
# Coronary Heart Disease                         5720
# Stroke                                         5720
# Smoking                                        5720
# Name: Topic, dtype: int64

# %%
df['TopicID'].value_counts()
# Out:
# T3     11440
# T9     11440
# T13    11440
# T10    11440
# T15     5720
# T11     5720
# T4      5720
# T1      5720
# T14     5720
# T12     5720
# T6      5720
# Name: TopicID, dtype: int64

# %%
df[df['Topic'] == 'Acute Myocardial Infarction (Heart Attack)'] # subset of data with just Topic = 'Acute Myocardial Infarction'
# Out:
#        Year LocationAbbr          LocationDesc Datasource   PriorityArea1  \
# 5739   2011           AL               Alabama      BRFSS  Million Hearts
# 5740   2011           AL               Alabama      BRFSS  Million Hearts
# 5741   2011           AL               Alabama      BRFSS  Million Hearts
# 5742   2011           AL               Alabama      BRFSS  Million Hearts
# 5743   2011           AL               Alabama      BRFSS  Million Hearts
# 5744   2011           AL               Alabama      BRFSS  Million Hearts
# 5745   2011           AL               Alabama      BRFSS  Million Hearts
# 5746   2011           AL               Alabama      BRFSS  Million Hearts
# 5747   2011           AL               Alabama      BRFSS  Million Hearts
# 5748   2011           AL               Alabama      BRFSS  Million Hearts
# 5749   2011           AL               Alabama      BRFSS  Million Hearts
# 5750   2011           AL               Alabama      BRFSS  Million Hearts
# ...

# %%
df.isnull().sum()
# Out:
# Year                              0
# LocationAbbr                      0
# LocationDesc                      0
# Datasource                        0
# PriorityArea1                     0
# PriorityArea2                     0
# PriorityArea3                     0
# PriorityArea4                     0
# Category                          0
# Topic                             0
# Indicator                         0
# Data_Value_Type                   0
# Data_Value_Unit                   0
# Data_Value                    28768
# Data_Value_Alt                    0
# Data_Value_Footnote_Symbol    57032
# Data_Value_Footnote           57032
# Confidence_Limit_Low          30167
# Confidence_Limit_High         30167
# Break_Out_Category                0
# Break_out                         0
# CategoryID                        0
# TopicID                           0
# IndicatorID                       0
# Data_Value_TypeID                 0
# BreakoutCategoryID                0
# ...

# %%
df['Data_Value_Alt']
# Out:
# 0         9.9
# 1        11.0
# 2        12.5
# 3        11.8
# 4         8.3
# 5         9.6
# 6        -2.0
# 7         3.8
# 8        13.4
# 9        27.0
# 10       15.2
# 11       30.7
# 12       11.5
# 13        9.5
# 14       10.2
# 15        9.6
# 16       -2.0
# 17       -2.0
# 18       -2.0
# 19        9.7
# 20       16.8
# 21       15.8
# 22        6.5
# 23        5.9
# 24        6.8
# 25        6.0
# 26        6.2
# 27        5.8
# 28       -2.0
# 29        1.7
#          ...
# 85770    -2.0
# 85771    -2.0
# 85772    -2.0
# 85773    -2.0
# 85774    33.9
# 85775    37.1
# 85776    -2.0
# 85777    -2.0
# 85778    61.0
# 85779    78.5
# 85780    74.1
# 85781    57.1
# 85782    65.4
# 85783    82.4
# 85784    14.0
# 85785    45.3
# 85786    80.6
# 85787    93.1
# 85788    83.2
# 85789    94.0
# 85790    79.3
# 85791    60.3
# 85792    67.3
# 85793    80.6
# 85794    71.0
# 85795    62.9
# 85796    53.1
# 85797    59.2
# 85798    72.2
# 85799    57.6
# ...

# %%
df['Break_Out_Category'].value_counts()
# Out:
# Race       39000
# Age        23400
# Gender     15600
# Overall     7800
# Name: Break_Out_Category, dtype: int64

# %%
df['Break_out'].value_counts()
# Out:
# Non-Hispanic Black    7800
# Female                7800
# Non-Hispanic Asian    7800
# Overall               7800
# Hispanic              7800
# Non-Hispanic White    7800
# Male                  7800
# Other                 7800
# 25-44                 3900
# 45-64                 3900
# 65+                   3900
# 35+                   3900
# 75+                   3900
# 18-24                 2860
# 20-24                 1040
# Name: Break_out, dtype: int64

# %%
male = df[df['Break_out'] == 'Male'] # only males

# %%
male[male['Topic'] == 'Acute Myocardial Infarction (Heart Attack)']
# Out:
#        Year LocationAbbr          LocationDesc Datasource   PriorityArea1  \
# 5741   2011           AL               Alabama      BRFSS  Million Hearts
# 5742   2011           AL               Alabama      BRFSS  Million Hearts
# 5763   2011           AK                Alaska      BRFSS  Million Hearts
# 5764   2011          USM  Median of all states      BRFSS  Million Hearts
# 5765   2011           AK                Alaska      BRFSS  Million Hearts
# 5787   2011           AZ               Arizona      BRFSS  Million Hearts
# 5788   2011           AZ               Arizona      BRFSS  Million Hearts
# 5809   2011           AR              Arkansas      BRFSS  Million Hearts
# 5810   2011           AR              Arkansas      BRFSS  Million Hearts
# 5831   2011           CA            California      BRFSS  Million Hearts
# 5832   2011           CA            California      BRFSS  Million Hearts
# 5854   2011           CO              Colorado      BRFSS  Million Hearts
# ...

# %%
df[df['Data_Value_Type'] == 'Age-Standardized']
# Out:
#        Year LocationAbbr          LocationDesc Datasource PriorityArea1  \
# 0      2011           AL               Alabama      BRFSS          None
# 3      2011           AL               Alabama      BRFSS          None
# 4      2011           AL               Alabama      BRFSS          None
# 13     2011           AL               Alabama      BRFSS          None
# 14     2011           AL               Alabama      BRFSS          None
# 16     2011           AL               Alabama      BRFSS          None
# 19     2011           AL               Alabama      BRFSS          None
# 20     2011           AL               Alabama      BRFSS          None
# 22     2011           AK                Alaska      BRFSS          None
# 24     2011           AK                Alaska      BRFSS          None
# 26     2011           AK                Alaska      BRFSS          None
# 35     2011           AK                Alaska      BRFSS          None
# ...

# %%
df['Data_Value_Type'].value_counts()
# Out:
# Crude               54600
# Age-Standardized    31200
# Name: Data_Value_Type, dtype: int64

# %% [markdown]
# # Mortality
# CDC

# %%
# mort15 = pd.read_csv('./mortality/2015_data.csv')

# mort14 = pd.read_csv('./mortality/2014_data.csv')

# mort13 = pd.read_csv('./mortality/2013_data.csv')

# mort12 = pd.read_csv('./mortality/2012_data.csv')

# mort11 = pd.read_csv('./mortality/2011_data.csv')

# %% [markdown]
# Small Heart Disease Data

# %%
hd = pd.read_csv('/Users/lu/Downloads/Heart.csv')

# %%
hd.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1
